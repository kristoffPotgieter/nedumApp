# %%
import pandas as pd

df = pd.read_excel('metadata/options_and_param.xlsx',sheet_name= 'parameters').set_index('parameters')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/k7/7pfy_t7d11bckpngtmww9l5r0000gn/T/ipykernel_59960/1840786865.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel('metadata/options_and_param.xlsx',sheet_name= 'parameters').set_index('parameters')
#       4 df.to_csv('metadata/options_and_param.csv')
#
# ~/.conda/envs/anaconda/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv('metadata/options_and_param.xlsx')
df.to_csv('metadata/options_and_param.csv')

# %%
import pandas as pd
import os
scenarioDict={"Baseline":"142", "Alternative":"212"}
scenario = '142'
scenPath = "modelOutputs/outputs/floods10_P11_C11_scenario"+scenario+"/plots/"
outputList= os.listdir(scenPath)
output = pd.DataFrame(outputList,columns=['file'])
output['title'] = output.file.str.replace('_'," ").str.replace('.png',"")
output['datafile'] = output.file.str.replace('png','csv')
output['type'] = 'output'
output
# Out:
# /var/folders/k7/7pfy_t7d11bckpngtmww9l5r0000gn/T/ipykernel_59960/2701565175.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   output['title'] = output.file.str.replace('_'," ").str.replace('.png',"")
#                                                   file  \
# 0                      fluviald_structures_damages.png
# 1          fluvialu_formal_content_2d_sim_shareinc.png
# 2                    pluvial_formal_content_2d_sim.png
# 3    pluvial_subsidized_structure_2d_data_shareinc.png
# 4                pluvial_informal_structure_2d_sim.png
# ..                                                 ...
# 203                  C_MERITDEM_1_severity_distrib.png
# 204     fluviald_backyard_content_2d_data_shareinc.png
# 205                       pluvial_contents_damages.png
# 206    fluviald_subsidized_content_2d_sim_shareinc.png
# 207                     pluvial_structures_damages.png
#
# ...

# %%
import pandas as pd
import os
scenarioDict={"Baseline":"142", "Alternative":"212"}
scenario = '142'
scenPath = "modelOutputs/outputs/input_plots/"
outputList= os.listdir(scenPath)
output = pd.DataFrame(outputList,columns=['file'])
output['title'] = output.file.str.replace('_'," ").str.replace('.png',"")
output['datafile'] = output.file.str.replace('png','csv')
output['type'] = 'input'
output
# Out:
# /var/folders/k7/7pfy_t7d11bckpngtmww9l5r0000gn/T/ipykernel_59960/3924377966.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   output['title'] = output.file.str.replace('_'," ").str.replace('.png',"")
#                                         file  \
# 0    contents_backyard_fract_K_destroyed.png
# 1                    coeff_land_informal.png
# 2                 interest_rate_scenario.png
# 3                            amenity_map.png
# 4                      FD_20yr_map_depth.png
# ..                                       ...
# 106                     FD_5yr_map_depth.png
# 107                    P_100yr_map_depth.png
# 108                    FU_200yr_map_area.png
# 109                     FU_50yr_map_area.png
# 110                    FU_75yr_map_depth.png
#
#                                    title  \
# 0    contents backyard fract K destroyed
# 1                    coeff land informal
# 2                 interest rate scenario
# ...
